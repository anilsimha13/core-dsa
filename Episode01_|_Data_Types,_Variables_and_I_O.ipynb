# %% [markdown]
# <a href="https://colab.research.google.com/github/anilsimha13/core-dsa/blob/main/Episode01_%7C_Data_Types%2C_Variables_and_I_O.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Episode01 | Data Types, Variables and I/O

# %% [markdown]
# _Topics Covered_
# - Computer understands only 0 & 1
# - Human understandable language is High Level Language like (Python, Java, C, C++)
# - Syntax is the Grammer for the programming language
# - IDE (Integrated Development Environment) like pycharm,vscode,Jupyter, Google Collab, etc...)
# - `print` is a function
# - Python is a case-sensitive language
# - Data types
# - `type` function is used to check which data type the given variable is
# - `strings`
# - `Boolean`
# - `Variables`
# - `Input` function

# %% [markdown]
# ## print

# %%
print('Hello World!')
# Out:
# Hello World!

# %%
print(13)
# Out:
# 13

# %%
print('6+5')
# Out:
# 6+5

# %%
print(6+7)
# Out:
# 13

# %% [markdown]
# ## Data types
# - Integers
# - Float
# - Strings
# - Bool
# - None

# %%
type(13)
# Out:
# int

# %%
type(3.0)
# Out:
# float

# %%
type(3.)
# Out:
# float

# %%
type('Thirteen')
# Out:
# str

# %%
print(type(13))
print(type(13.0))
print(type('Thirteen'))
print(type("13"))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'str'>

# %%
print(type('Goat'))
# Out:
# <class 'str'>

# %%
print(type(True))
print(type(False))
print(type(None))
# Out:
# <class 'bool'>
# <class 'bool'>
# <class 'NoneType'>

# %% [markdown]
# ## Stings
# - 'Single Quotes'
# - "Double Quotes"
# - '''Double triple Quotes'''
# - """ Multiline comments"""

# %%
print('Single Quotes')
print("Double Quotes")
print('''Double triple Quotes
          Line One
          Line two
          Line three
          Line four
''')
print(""" Multiline comments
          Line one
          Line two
          line three
          line four
""")
# Out:
# Single Quotes
# Double Quotes
# Double triple Quotes
#           Line One
#           Line two
#           Line three
#           Line four
#
#  Multiline comments
#           Line one
#           Line two
#           line three
#           line four

# %% [markdown]
# ## Boolean

# %%
print(type(True))
print(type(False))
# Out:
# <class 'bool'>
# <class 'bool'>

# %%
2==3
# Out:
# False

# %%
2 != 3
# Out:
# True

# %%
3 == 3
# Out:
# True

# %%
True == False
# Out:
# False

# %% [markdown]
# ## Variables
# - Variable should start with Alphabets or underscore
# - These are case-sensitive
# - Name should not have any special charaters
# - It can be alphanumeric

# %%
x = 5
y = 8
print(x+y)
# Out:
# 13

# %%
firtName = "Anil Simha"
lastName = "Tallapragada"
fullName = firtName + " " + lastName
print(fullName)
# Out:
# Anil Simha Tallapragada

# %%
x = 5
x = 7
x = 10
print(x)
# Out:
# 10

# %%
x = 9
X = 10
print(x)
print(X)
# Out:
# 9
# 10

# %% [markdown]
# ## Input Function
# - By default the type of Input value is string

# %%
product = input("Enter the product name: ")
print(product)

# %%
number = input("Enter a number: ")
print(number)
type(number)

# %%
# Take two user inputs and add them

userA = int(input('Please enter the number for user A '))
userB = int(input('Please enter the number for user B '))
print(userA + userB)
