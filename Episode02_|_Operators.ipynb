# %% [markdown]
# <a href="https://colab.research.google.com/github/anilsimha13/core-dsa/blob/main/Episode02_%7C_Operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  Episode02 |  Operators
#
# _Things to remember_
# - Arithmetic operators
# - Cannot add/Subtract a number to the string
# - Concatenation
# - Division operator always give you the floating number as output
# - Floor operator always give you the left intiger
# - Mod always give you the reminder
# - BODMAS
# - Comparison operator always returns Boolean
# - Assignment Operators
# - Float to Int, int to float, int to string, string to int
# - Cannot directly convert String with decimal to Integer - Instead do `int(float('2.9'))`

# %% [markdown]
# ## Arithmetic operators
# - Addition
# - Subtraction
# - Division
# - Multiplication
# - Mod (%)
# - Floor division (//)
# - To the power (**)

# %%
print(1+12)
print(1.0+12)
print(1.0+12.0)
print(9-7)
print(9-1.0)
print("Anil"*3)
print(9*3)
print(2**3)
print(10//5)
print(10//3)
print(-10//3)
print(10%5)
print(10%2)
print(10%3)
# Out:
# 13
# 13.0
# 13.0
# 2
# 8.0
# AnilAnilAnil
# 27
# 8
# 2
# 3
# -4
# 0
# 0
# 1

# %%
print("A"+"N"+"I"+"L")
# Out:
# ANIL

# %%
print(10/2)
print(1/1.0)
# Out:
# 5.0
# 1.0

# %% [markdown]
# ## Comparison
# - Double Equal
# - Not Equal
# - Less and greater than
# - Lessthan equal or greaterthan equal

# %%
print(True == True)
print(True == False)
print(True != False)
# Out:
# True
# False
# True

# %%
print(2 == 2.0)
# Out:
# True

# %%
"Anil" == "anil"
# Out:
# False

# %%
print(2>3)
print(3<2)
print(2<=2)
print(2>=2 )
print('2'==2 )
# Out:
# False
# False
# True
# True
# False

# %% [markdown]
# ## Assignment Operators
# - -=
# - +=
# - /=
# - *=

# %%
marks = 80
graceMarks = 5

marks = marks + graceMarks
print(marks)

marks = 80
graceMarks = 5
marks += graceMarks
print(marks)
# Out:
# 85
# 85

# %%
x = 10
y = 3
x *= y
print(x)
# Out:
# 30

# %%
x/=y
print(x)
# Out:
# 10.0

# %%
x -=y
print(x)
# Out:
# 7.0

# %%
x *=y
print(x)
# Out:
# 21.0

# %% [markdown]
# ## Float to Int

# %%
str(3)
# Out:
# '3'

# %%
z = 9.8
print(int(z))
w = 9
print(float(w))
# Out:
# 9
# 9.0

# %%
float('2.9')
# Out:
# 2.9

# %%
int(float('2.9'))
# Out:
# 2

# %%
0 == False
# Out:
# True

# %%
1 == True
# Out:
# True

# %% [markdown]
# ## Logical Operators
# - AND
# - NOT
# - OR

# %%
print(True and True)
print(True and False)
print(False and False)
print(True or True)
print(True or False)
print(False or False)
print(not True)
print(not False)
# Out:
# True
# False
# False
# True
# True
# False
# False
# True

# %%
print(2>=3 and 2==3)
print(3>=3 or 2==3)
# Out:
# False
# True
